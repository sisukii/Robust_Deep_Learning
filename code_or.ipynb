# %%
from autograd import numpy as np
from autograd import grad

from matplotlib import pyplot as plt

# %matplotlib inline

# %%
def f_square_2(x, y):
    if (np.abs(x-2)-0.5)*(np.abs(y-6.5)-2) >=0 or (np.abs(x-6.5)-2)*(np.abs(y-2)-0.5) >= 0: 
        return 0.
    else: return -1.

def f_square_1(x):
    if (np.abs(x-2)-0.5)*(np.abs(x-6.5)-2) >= 0: 
        return 0.
    else:
        return -1.
def f_piramid_1(x):
    return np.min((np.abs(x-2) - 1, 0))
#     if (np.abs(x-2)-1) >= 0: 
#         if (np.abs(x-7)-2) >=0:
#             return 0.     
#         if (np.abs(x-7)-2) <=0:
#             return (np.abs(x-7)-2)/2
#     else:
#         return (np.abs(x-2)-1)

# %%
x = np.arange(0, 10, 0.1)
f = [f_piramid_1(elem) for elem in x]
plt.plot(x, f)

# %%
x = np.arange(0, 10, 0.1)
f = [f_square_1(elem) for elem in x]
plt.plot(x, f)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure(figsize=(10,8))
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(0, 10, 0.1)
Y = np.arange(0, 10, 0.1)
X, Y = np.meshgrid(X, Y)
Z=[]
for i in range(len(X)):
    Z.append([f_square_2(a, b) for a,b in zip(X[i],Y[i])])

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
X = np.arange(0, 10, 0.1)
Y = np.arange(0, 10, 0.1)
X, Y = np.meshgrid(X, Y)
Z=[]
for i in range(len(X)):
    Z.append([np.exp(-f_square_2(a, b)/0.4) for a,b in zip(X[i],Y[i])])
Z = np.array(Z)

# %%
x =[]
for _ in range(500):
    for i in range(100):
        x.append([np.random.choice(np.arange(0, 10, 0.1), p=Z[:, i]/Z[:, i].sum())])

# %%
y =[]
for _ in range(500):
    for i in range(100):
        y.append([np.random.choice(np.arange(0, 10, 0.1), p=Z[i]/Z[i].sum())])

# %%
from mpl_toolkits.mplot3d import Axes3D 
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')

hist, xedges, yedges = np.histogram2d(np.array(x).ravel(), np.array(y).ravel(), bins=15, range=[[0.1, 10], [0.1, 10]])

# Construct arrays for the anchor positions of the 16 bars.
xpos, ypos = np.meshgrid(xedges[:-1] + 0.15, yedges[:-1] + 0.15, indexing="ij")
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = np.zeros_like(xpos)

# Construct arrays with the dimensions for the 16 bars.
dx = dy = 0.5 * np.ones_like(zpos)
dz = hist.ravel()



ax.bar3d(xpos, ypos, zpos, dx, dy, dz, color='b', zsort='average')

plt.show()

# %%
grad_square_1 = grad(f_square_1)
grad_square_2x = grad(f_square_1)

# %%
grad_piramid_1(1.45)
# Out:
# -1.0

# %%
lr = 0.5
x =[]
norma =[]

for i in range(100):
    x_k = np.random.rand(1) * 10
    #while (f_square_1(x_k) == 0.):
    for i in range(50):
        add = grad_square_1(x_k)
        add *= -(lr / 2)
        norm = np.random.normal(0, 1.)
        add += norm 
        x_k += norm
        norma.append(norm)
    x.append(x_k.tolist())
# Out:
# /home/sisuki/anaconda2/envs/py3k/lib/python3.6/site-packages/autograd/tracer.py:14: UserWarning: Output seems independent of input.
#   warnings.warn("Output seems independent of input.")
# /home/sisuki/anaconda2/envs/py3k/lib/python3.6/site-packages/autograd/tracer.py:14: UserWarning: Output seems independent of input.
#   warnings.warn("Output seems independent of input.")
# /home/sisuki/anaconda2/envs/py3k/lib/python3.6/site-packages/autograd/tracer.py:14: UserWarning: Output seems independent of input.
#   warnings.warn("Output seems independent of input.")
# /home/sisuki/anaconda2/envs/py3k/lib/python3.6/site-packages/autograd/tracer.py:14: UserWarning: Output seems independent of input.
#   warnings.warn("Output seems independent of input.")
# /home/sisuki/anaconda2/envs/py3k/lib/python3.6/site-packages/autograd/tracer.py:14: UserWarning: Output seems independent of input.
#   warnings.warn("Output seems independent of input.")
# ...

# %%
distr = []
for i in range(100):
    distr.append(np.random.normal(0., 2.))

# %%
fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(norma, histtype='step', bins = 20)


# Tweak spacing to prevent clipping of ylabel
# fig.tight_layout()
plt.show()

# %%
lr = 0.5
lr1 = 1.
x =[]
grad_piramid_1 = grad(f_piramid_1)

for i in range(10):
    x_k = np.random.rand(1) * 10
    print(x_k)
    while (f_piramid_1(x_k) > -0.5):
        print(grad_piramid_1(x_k))
        add = grad_piramid_1(x_k)
        add *= -(lr / 2.)
        norm = lr1 * np.random.normal(0., np.sqrt(lr), x_k.shape)
        add += norm 
        x_k += norm
        lr1 /= 2.
    x.append(x_k.tolist())
# Out:
# [4.60958058]
# /home/sisuki/anaconda2/envs/py3k/lib/python3.6/site-packages/autograd/tracer.py:14: UserWarning: Output seems independent of input.
#   warnings.warn("Output seems independent of input.")
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda2/envs/py3k/lib/python3.6/site-packages/autograd/core.py in vspace(value)
#     224     try:
# --> 225         return VSpace.mappings[type(value)](value)
#     226     except KeyError:
#
# KeyError: <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-190-bb72a6767adf> in <module>()
#       8     print(x_k)
#       9     while (f_piramid_1(x_k) > -0.5):
# ---> 10         print(grad_piramid_1(x_k))
#      11         add = grad_piramid_1(x_k)
#      12         add *= -(lr / 2.)
#
# ...

# %%
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np

tfd = tfp.distributions
dtype = np.float32

samples = []
for i in range(100):
    with tf.Session(graph=tf.Graph()) as sess:
    # Set up random seed for the optimizer
    
        tf.random.set_random_seed(i)
        x = tf.Variable(tf.random.uniform((1,), minval=0, maxval=10.), trainable=True)

        loss = tf.minimum(tf.abs(x-2) - 1, 0)#((tf.abs(x-2)-0.5)*(tf.abs(x-6.5)-2)/tf.abs((tf.abs(x-2)-0.5)*(tf.abs(x-6.5)-2)), 0)

        # Set up the learning rate with a polynomial decay
        global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = .3
        end_learning_rate = 1e-4
        decay_steps = 1e4
        learning_rate = tf.train.polynomial_decay(starter_learning_rate,
                                                global_step, decay_steps,
                                                end_learning_rate, power=1.)

        # Set up the optimizer
        optimizer_kernel = tfp.optimizer.StochasticGradientLangevinDynamics(
          learning_rate=learning_rate, preconditioner_decay_rate=0.99)

        optimizer = optimizer_kernel.minimize(loss)

        init = tf.global_variables_initializer()
        # Number of training steps
        training_step = 0
        # Record the steps as and treat them as samples

        sess.run(init)

        while loss.eval({x: sess.run(x)}) > -0.9:
            sess.run([optimizer, loss])
            sample = [sess.run(x)]
        samples.append(sample[0])

    #         samples_ = np.concatenate(samples, axis=-1)
        #print('sample', samples)

# %%
x[:10]
# Out:
# [[4.55756395988537],
#  [2.15595444361678],
#  [8.127137653885011],
#  [1.7979323936625344],
#  [7.957323005385412],
#  [6.508563034323163],
#  [2.374836456962197],
#  [5.341425120099247],
#  [6.271951010021466],
#  [6.707368481412991]]

# %%
lr = 1.
#x =[]

for i in range(10):
    x_k = np.random.rand(1) * 9
    y_k = np.random.rand(1) * 9
    while (f_square_2(x_k, y_k) == 0):
#         add = grad_square_1(x_k)
#         add *= -(lr / 2)
        norm_x = np.random.normal(0., np.sqrt(lr), x_k.shape)
        norm_y = np.random.normal(0., np.sqrt(lr), x_k.shape)
#         add += norm 
        x_k += norm_x
        y_k += norm_y
    x.append(x_k.tolist())

# %%
def f_piramid(x, y):
    if (np.abs(x-2)-0.5)<= 0 and (np.abs(y-2)-0.5) <= 0: 
        return (np.abs(x-2)-0.5  + (np.abs(y-2)-0.5))
    else: 
        if (np.abs(y-6)-1) <= 0:
            return (np.abs(y-6)-1)
        else: return 0.

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure(figsize = (10,8))
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(0, 10, 0.1)
Y = np.arange(0, 10, 0.1)
X, Y = np.meshgrid(X, Y)
Z=[]
for i in range(len(X)):
    Z.append([f_piramid(a, b) for a,b in zip(X[i],Y[i])])

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility


fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')
X = np.arange(0, 10, 0.1)
Y = np.arange(0, 10, 0.1)
X, Y = np.meshgrid(X, Y)
Z=[]
for i in range(len(X)):
    Z.append([np.exp(-f_piramid(a, b)/0.2) for a,b in zip(X[i],Y[i])])
Z = np.array(Z)

x =[]
for _ in range(500):
    for i in range(100):
        x.append([np.random.choice(np.arange(0, 10, 0.1), p=Z[:, i]/Z[:, i].min()/Z[:, i].sum())])

y =[]
for _ in range(500):
    for i in range(100):
        p=Z[i]/Z[i].min()/Z[i].sum()
#         print(p.sum())
#         print(Z[i])
        y.append([np.random.choice(np.arange(0, 10, 0.1), p=Z[i]/Z[i].sum())])

hist, xedges, yedges = np.histogram2d(np.array(y).ravel(), np.array(x).ravel(),  bins=15, range=[[0.1, 10], [0.1, 10]])

# Construct arrays for the anchor positions of the 16 bars.
xpos, ypos = np.meshgrid(xedges[:-1] + 0.15, yedges[:-1] + 0.15, indexing="ij")
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = np.zeros_like(xpos)

# Construct arrays with the dimensions for the 16 bars.
dx = dy = 0.5 * np.ones_like(zpos)
dz = hist.ravel()


ax.bar3d(xpos, ypos, zpos, dx, dy, dz, color='b', zsort='average')

plt.show()

# %%
x = np.random.ranf(100) * 10.

# %%
xs = [np.exp(-f_square_1(elem)/0.2) for elem in np.arange(0, 10, 0.05)]
xs = np.array(xs)
xs = xs/min(xs)/sum(xs)

# %%
x =[]
for _ in range(320):
    x.append(np.random.choice(np.arange(0, 10, 0.05), p=xs))

# %%
plt.hist(x, bins=20, range=(0.1, 9.9))
# Out:
# (array([ 0.,  0.,  2., 25., 32.,  0.,  0.,  0.,  0., 27., 23., 37., 28.,
#         36., 34., 38., 33.,  5.,  0.,  0.]),
#  array([0.1 , 0.59, 1.08, 1.57, 2.06, 2.55, 3.04, 3.53, 4.02, 4.51, 5.  ,
#         5.49, 5.98, 6.47, 6.96, 7.45, 7.94, 8.43, 8.92, 9.41, 9.9 ]),
#  <a list of 20 Patch objects>)
